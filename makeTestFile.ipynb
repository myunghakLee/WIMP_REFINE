# %%
from matplotlib import pyplot as plt
import numpy as np
import json
import math
import csv
import os

# %%
def denormalization(arr, angle, translation):

    theta = (angle)/180*math.pi
    c, s = np.cos(theta), np.sin(theta)
    R = np.array(((c, -s), (s, c)))
    
    #rotate
    arr = np.array(R.dot(arr.transpose())).transpose()
    #translate
    arr += translation
#     arr[...,0] += (AGENT[19,0] - AGENT[0,0])
#     arr[...,1] += (AGENT[19,1] - AGENT[0,1])
    return arr

# %%
def prediction(root_dir, file):
    json_dict = {}

    with open(root_dir + file, 'r') as json_data:
        json_dict = json.load(json_data)

    preds = np.array(json_dict['preds'][0])[...,:2]
    preds = np.array([denormalization(p, -json_dict['rotation'], -np.array(json_dict['translation'])) for p in preds])
    seq_id = int(json_dict['csv_file'].split('.')[0])
    return preds, seq_id

# %%
# !pip install numpy-quaternion

# %%
from tqdm.notebook import tqdm
from argoverse.evaluation.competition_util import generate_forecasting_h5

# %%
root_dir = ["ResultsFile/" + d + "/" for d in(os.listdir("ResultsFile"))]
output_path = ["competition_files/" + d + "/" for d in(os.listdir("ResultsFile"))]
print(root_dir)
print(output_path)
for i in range(len(root_dir)):
    os.makedirs(output_path[i], exist_ok = True)

    file_list = os.listdir(root_dir[i])
    output_all = {}
    for file in tqdm(file_list):
        p, seq_id = prediction(root_dir[i], file)
        output_all[seq_id] = p 
    generate_forecasting_h5(output_all, output_path[i]) #this might take awhile
# Out:
# ['ResultsFile/dist_0_01/']
# ['competition_files/dist_0_01/']
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=78143.0), HTML(value='')))
# 1181/78143
# 78143/78143

# %%
def prediction_draw(root_dir, file):
    json_dict = {}

    with open(root_dir + file, 'r') as json_data:
        json_dict = json.load(json_data)
    print(json_dict['csv_file'])
    print(json_dict.keys())
    preds = np.array(json_dict['preds'][0])[...,:2]
    preds = np.array([denormalization(p, -json_dict['rotation'], -np.array(json_dict['translation'])) for p in preds])
    seq_id = int(json_dict['csv_file'].split('.')[0])
    return preds, seq_id

# %%
for file in tqdm(file_list):
    print(file)
    p, seq_id = prediction_draw(root_dir[i], file)
    break
    output_all[seq_id] = p
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=78143.0), HTML(value='')))
# 20691.json
# 20691.csv
# dict_keys(['preds', 'waypoint_preds', 'rotation', 'translation', 'csv_file', 'city', 'agent_labels'])
